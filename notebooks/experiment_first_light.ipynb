# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np

matplotlib.rcParams['figure.figsize'] = (10.0, 10.0)

# %%
experiment = '/Users/youngtodd/segment/experiments/five_september/liver'

def load_results(file, path=experiment):
    path = os.path.join(path, file)
    arry = np.load(path)
    return arry

# %%
testdice_avg = load_results('testdice_avgs.npy')
testdice_val = load_results('testdice_vals.npy')
trainloss_avg = load_results('trainloss_avgs.npy')
trainloss_val = load_results('trainloss_vals.npy')
traindice_val = load_results('traindice_vals.npy')
traindice_avg = load_results('traindice_avgs.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-3134a713de89> in <module>()
# ----> 1 testdice_avg = load_results('testdice_avgs.npy')
#       2 testdice_val = load_results('testdice_vals.npy')
#       3 trainloss_avg = load_results('trainloss_avgs.npy')
#       4 trainloss_val = load_results('trainloss_vals.npy')
#       5 traindice_val = load_results('traindice_vals.npy')
#
# <ipython-input-27-86bcdbbdf45b> in load_results(file, path)
#       3 def load_results(file, path=experiment):
#       4     path = os.path.join(path, file)
# ----> 5     arry = np.load(path)
#       6     return arry
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     370     own_fid = False
#     371     if isinstance(file, basestring):
# --> 372         fid = open(file, "rb")
#     373         own_fid = True
#     374     elif is_pathlib_path(file):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/youngtodd/segment/experiments/five_september/liver/testdice_avgs.npy'

# %%
plt.plot(traindice_avg)
